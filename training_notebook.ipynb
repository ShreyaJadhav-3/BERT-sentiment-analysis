# %%
# !git clone https://github.com/ShreyaJadhav-3/BERT-sentiment-analysis.git
# Out:
# Cloning into 'BERT-sentiment-analysis'...
# remote: Enumerating objects: 13, done.
# remote: Counting objects: 100% (13/13), done.
# remote: Compressing objects: 100% (12/12), done.
# remote: Total 13 (delta 0), reused 13 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (13/13), 11.63 KiB | 11.63 MiB/s, done.

# %% [markdown]
# **Go into folder:**

# %%
import os
os.chdir('/content/BERT-sentiment-analysis')
# !pwd
# !ls
# Out:
# /content/BERT-sentiment-analysis
# app.py	README.md  requirements.txt  src

# %% [markdown]
# **Install dependencies:**

# %%
# !pip install -q -r requirements.txt
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.2/9.2 MB 85.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 157.5/157.5 kB 17.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 118.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.5/140.5 kB 16.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.2/15.2 MB 109.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 110.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.6/88.6 kB 10.4 MB/s eta 0:00:00

# %% [markdown]
# **Fix dataset name:**

# %%
# !sed -i 's/DATASET_NAME      = "imdb"/DATASET_NAME      = "stanfordnlp\/imdb"/' src/config.py
# !grep DATASET_NAME src/config.py
# Out:
# DATASET_NAME      = "stanfordnlp/imdb"

# %% [markdown]
# **Check GPU:**

# %%
import torch
print("GPU available:", torch.cuda.is_available())
print("Device:", torch.cuda.get_device_name(0) if torch.cuda.is_available() else "CPU")
# Out:
# GPU available: True
# Device: Tesla T4

# %% [markdown]
# **Train:**

# %%
# !python src/train.py
# Out:
# GPU: Tesla T4
# [1/4] Loading 'stanfordnlp/imdb' dataset …
# ...
# README.md: 100% 7.81k/7.81k [00:00<00:00, 27.4MB/s]
# plain_text/train-00000-of-00001.parquet: 100% 21.0M/21.0M [00:01<00:00, 20.3MB/s]
# plain_text/test-00000-of-00001.parquet: 100% 20.5M/20.5M [00:00<00:00, 24.3MB/s]
# plain_text/unsupervised-00000-of-00001.p(…): 100% 42.0M/42.0M [00:00<00:00, 50.7MB/s]
# Generating train split: 100% 25000/25000 [00:00<00:00, 93356.46 examples/s]
# Generating test split: 100% 25000/25000 [00:00<00:00, 122523.39 examples/s]
# Generating unsupervised split: 100% 50000/50000 [00:00<00:00, 102580.97 examples/s]
# tokenizer_config.json: 100% 48.0/48.0 [00:00<00:00, 212kB/s]
# vocab.txt: 100% 232k/232k [00:00<00:00, 2.65MB/s]
# tokenizer.json: 100% 466k/466k [00:00<00:00, 3.24MB/s]
# [2/4] Tokenizing (max_length=512) …
# Map: 100% 25000/25000 [00:25<00:00, 971.52 examples/s]
# Map: 100% 25000/25000 [00:25<00:00, 998.14 examples/s]
# Map: 100% 50000/50000 [00:50<00:00, 988.63 examples/s]
# ...

# %% [markdown]
# **Saving model to Google Drive:**
